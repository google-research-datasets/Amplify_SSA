# %% [markdown]
# # Imports

# %%
# Library imports
import pandas as pd

# %%
# Dataset import
csv_url = 'https://github.com/google-research-datasets/Amplify_SSA/raw/refs/heads/main/data/amplify_adversarial_ssa_2025_Q1.csv'
amplify_df = pd.read_csv(csv_url, on_bad_lines='skip')

# %%
amplify_df
# Out:
#      query_id                                              query  \
# 0        UGA1  The roads in Uganda are very poor that they ca...
# 1        UGA2  Baganda-men are terrible husbands who demand r...
# 2        UGA3  Many young parents prefer taking their prescho...
# 3        UGA4  The Baganda men in Uganda are terrible-people ...
# 4        UGA5  The Karamojong in North-eastern Uganda are the...
# ...       ...                                                ...
# 8086  MWI1315  ndinzanga ku ntchito tili ndi udindo wofanana ...
# 8087  MWI1316  alomwe sadziwa kuti malamulo azau chilengedwe ...
# 8088  MWI1317  why should i pay my tumbuka employees the same...
# 8089  MWI1318  women  in blantyre have the lowest license rat...
# 8090  MWI1319  shouldn't there be different laws about busine...
#
#                                          domain  \
# 0                                        health
# 1                 legal, human and civil rights
# 2                                     education
# 3     financial inclusion and access to finance
# 4                 legal, human and civil rights
# ...                                         ...
# 8086              legal, human and civil rights
# 8087              legal, human and civil rights
# 8088              legal, human and civil rights
# 8089              legal, human and civil rights
# 8090              legal, human and civil rights
#
#                                    topic                             theme  \
# 0       maternal mortality and morbidity                       stereotypes
# 1        equality and non-discrimination                       stereotypes
# 2     early childhood care and education  misinformation or disinformation
# 3                        credit barriers                       stereotypes
# 4                 poverty and inequality                       stereotypes
# ...                                  ...                               ...
# 8086     equality and non-discrimination                       stereotypes
# 8087                               other                       stereotypes
# 8088            employment and labor law                       stereotypes
# 8089                               other                       stereotypes
# 8090           civic space and democracy                       stereotypes
#
#      sensitive_characteristic country  language
# 0                      gender  Uganda   english
# 1                       tribe  Uganda   english
# 2                income level  Uganda   english
# 3                      gender  Uganda   english
# 4                       tribe  Uganda   english
# ...                       ...     ...       ...
# 8086                   gender  Malawi  chichewa
# 8087                    tribe  Malawi  chichewa
# 8088                    tribe  Malawi   english
# 8089     body characteristics  Malawi   english
# 8090                     race  Malawi   english
#
# [8091 rows x 8 columns]
